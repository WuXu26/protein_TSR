# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
path = '/home/linc/c00219805/Research/Protien_Database/extracted_new_samples/testing/sample_CATH_100/theta29_dist35'

# %%
df = pd.read_csv(path+'/test.csv',index_col = 0,header=0)
print(df.head(1))
# Out:
#                          ALPHA/ALPHA BARREL-1V5C  ALPHA/ALPHA BARREL-1W6J  \
# ALPHA/ALPHA BARREL-1V5C                    100.0                13.363985
#
#                          ALPHA/ALPHA BARREL-1WU4  ALPHA/ALPHA BARREL-1WZZ  \
# ALPHA/ALPHA BARREL-1V5C                41.602325                33.785074
#
#                          ALPHA/ALPHA BARREL-1X81  ALPHA/ALPHA BARREL-2AHF  \
# ALPHA/ALPHA BARREL-1V5C                14.105124                37.076754
#
#                          ALPHA/ALPHA BARREL-2B4F  ALPHA/ALPHA BARREL-2BED  \
# ALPHA/ALPHA BARREL-1V5C                 51.62174                 14.13841
#
#                          ALPHA/ALPHA BARREL-2C3E  ALPHA/ALPHA BARREL-2D8L  \
# ALPHA/ALPHA BARREL-1V5C                27.940159                42.371083
#
#                              ...       BETA BARREL-4DW2  BETA BARREL-4DXI  \
# ALPHA/ALPHA BARREL-1V5C      ...              14.403353          14.96732
#
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 20))
ax =sns.heatmap(df, square = True, vmin=0, vmax=100)

# %%
fig = ax.get_figure()
fig.savefig(path+'/test.png')
